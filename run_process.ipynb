# %%
dbutils.notebook.run("/Workspace/Users/worada.wongtayan@gmail.com/Retail-Sales-ETL-Pipeline/bronze/bronze_fw",0,{"pipeline_name":"shop_name"})
dbutils.notebook.run("/Workspace/Users/worada.wongtayan@gmail.com/Retail-Sales-ETL-Pipeline/silver/silver_fw",0,{"pipeline_name":"shop_name"})

# %%
dbutils.notebook.run("/Workspace/Users/worada.wongtayan@gmail.com/Retail-Sales-ETL-Pipeline/bronze/bronze_fw",0,{"pipeline_name":"fact_sales"})
dbutils.notebook.run("/Workspace/Users/worada.wongtayan@gmail.com/Retail-Sales-ETL-Pipeline/silver/silver_fw",0,{"pipeline_name":"fact_sales"})
